# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !nvidia-smi
# Out:
# Mon Feb 28 13:05:34 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   55C    P8    30W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from IPython.display import Image, display

# %%
# !pip install opensimplex

# %%
# !ls
# Out:
# drive  sample_data

# %%
# %cd /content/drive/MyDrive/colab-sg2-ada/stylegan2-ada
# Out:
# /content/drive/MyDrive/colab-sg2-ada/stylegan2-ada

# %%
# %cd "/content/drive/My Drive/colab-sg2-ada/stylegan2-ada"
# !git config --global user.name "test"
# !git config --global user.email "test@test.com"
# !git fetch origin
# !git checkout origin/main -- train.py
# Out:
# /content/drive/My Drive/colab-sg2-ada/stylegan2-ada

# %%
# !python generate.py generate-images --network="/content/drive/MyDrive/colab-sg2-ada/stylegan2-ada/results/00002-resizepore-mirror-mirrory-11gb-gpu-bg-resumecustom/network-snapshot-000048.pkl" --seeds=0-3000 --outdir="./out3000/"
# Out:
# Imageio: 'ffmpeg-linux64-v3.3.1' was not found on your computer; downloading it now.
# Try 1. Download from https://github.com/imageio/imageio-binaries/raw/master/ffmpeg/ffmpeg-linux64-v3.3.1 (43.8 MB)
# 45929032/45929032 bytes (100.0%)
#   Done
# File saved as /root/.imageio/ffmpeg/ffmpeg-linux64-v3.3.1.
# Loading networks from "/content/drive/MyDrive/colab-sg2-ada/stylegan2-ada/results/00002-resizepore-mirror-mirrory-11gb-gpu-bg-resumecustom/network-snapshot-000048.pkl"...
# Setting up TensorFlow plugin "fused_bias_act.cu": Compiling... Loading... Done.
# Setting up TensorFlow plugin "upfirdn_2d.cu": Compiling... Loading... Done.
# Generating image for seed 0 (0/3001) ...
# Generating image for seed 1 (1/3001) ...
# Generating image for seed 2 (2/3001) ...
# Generating image for seed 3 (3/3001) ...
# Generating image for seed 4 (4/3001) ...
# Generating image for seed 5 (5/3001) ...
# Generating image for seed 6 (6/3001) ...
# Generating image for seed 7 (7/3001) ...
# ...

# %%
# !zip -r generated-out.zip /content/drive/MyDrive/colab-sg2-ada/stylegan2-ada/out
# Out:
# updating: content/drive/MyDrive/colab-sg2-ada/stylegan2-ada/out/ (stored 0%)
#   adding: content/drive/MyDrive/colab-sg2-ada/stylegan2-ada/out/target.png (deflated 0%)
#   adding: content/drive/MyDrive/colab-sg2-ada/stylegan2-ada/out/proj.mp4 (deflated 0%)
#   adding: content/drive/MyDrive/colab-sg2-ada/stylegan2-ada/out/proj.png (deflated 0%)
#   adding: content/drive/MyDrive/colab-sg2-ada/stylegan2-ada/out/dlatents.npz (deflated 94%)
