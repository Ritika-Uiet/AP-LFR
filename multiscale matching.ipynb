# %%
https://github.com/Logeswaran123/Multiscale-Template-Matching

# %%
# %cd "/content/drive/My Drive/"
# !git clone https://github.com/Logeswaran123/Multiscale-Template-Matching.git
# Out:
# /content/drive/My Drive
# Cloning into 'Multiscale-Template-Matching'...
# remote: Enumerating objects: 29, done.
# remote: Total 29 (delta 0), reused 0 (delta 0), pack-reused 29
# Unpacking objects: 100% (29/29), done.

# %%
pwd
# Out:
# '/content/drive/MyDrive'

# %%
# %cd "/content/drive/MyDrive/Multiscale-Template-Matching"
# Out:
# /content/drive/MyDrive/Multiscale-Template-Matching

# %%
# !python matching3.py --template /content/drive/MyDrive/testcrop --images /content/drive/MyDrive/sample
# Out:
# [ WARN:0@0.389] global /io/opencv_contrib/modules/xfeatures2d/misc/python/shadow_sift.hpp (13) SIFT_create DEPRECATED: cv.xfeatures2d.SIFT_create() is deprecated due SIFT tranfer to the main repository. https://github.com/opencv/opencv/issues/16736
# ******Running KP_DES******
# **********KP_DES************
# ******inside temp_query_match******
# ------------------------------
# 1_LI_1-0.png
# ------------------------------
# ************************
# Copy of Copy of 1_LI_1.png
# ************************
# key_matches:  130
# find_match_time:  0.013525623000077758
# queryborder:  [[[ 97.87977 262.86652]
#   [ 97.90072 705.395  ]
#   [540.43353 705.42523]
#   [540.40955 262.87338]]]
# Object found- 119/60
# [[[   0.    0.]
#   [   0. 1023.]
#   [1023. 1023.]
#   [1023.    0.]]]
# {'na': [], 'Copy of Copy of 1_LI_1.png': [('1_LI_1-0.png', [97, 262, 540, 705])]}
# ------------------------------
# 1_LI_1-1.png
# ------------------------------
# ************************
# ...
