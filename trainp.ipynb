# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
# !nvidia-smi
# Out:
# Thu Jan  6 12:36:24 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   33C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
import os
if os.path.isdir("/content/drive/My Drive/colab-sg2-ada"):
    # %cd "/content/drive/My Drive/colab-sg2-ada/stylegan2-ada"
else:
    #install script
    # %cd "/content/drive/My Drive/"
    # !mkdir colab-sg2-ada
    # %cd colab-sg2-ada
    # !git clone https://github.com/dvschultz/stylegan2-ada
    # %cd stylegan2-ada
    # !mkdir downloads
    # !mkdir datasets
# Out:
# /content/drive/My Drive/colab-sg2-ada/stylegan2-ada

# %%
# %cd "/content/drive/My Drive/colab-sg2-ada/stylegan2-ada"
# !git config --global user.name "test"
# !git config --global user.email "test@test.com"
# !git fetch origin
# !git checkout origin/main -- train.py
# Out:
# /content/drive/My Drive/colab-sg2-ada/stylegan2-ada

# %%
#update this to the path to your image folder
dataset_path = "/content/drive/MyDrive/resized1024"
#give your dataset a name
dataset_name = "resizepore"

#you don't need to edit anything here
# !python dataset_tool.py create_from_images ./datasets/{dataset_name} {dataset_path}
# Out:
# Loading images from "/content/drive/MyDrive/resized1024"
# Creating dataset "./datasets/resizepore"
# dataset_tool.py:97: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   'data': tf.train.Feature(bytes_list=tf.train.BytesList(value=[quant.tostring()]))}))
# Added 373 images.

# %%
#this name must EXACTLY match the dataset name you used when creating the .tfrecords file
dataset_name = "resizepore"
#how often should the model generate samples and a .pkl file
snapshot_count = 2
#should the images be mirrored left to right?
mirrored = True
#should the images be mirrored top to bottom?
mirroredY = True
#metrics? 
metric_list = None
#augments
augs = "bg"

#
# this is the most important cell to update
#
# running it for the first time? set it to ffhq(+resolution)
# resuming? get the path to your latest .pkl file and use that
resume_from = "/content/drive/MyDrive/colab-sg2-ada/stylegan2-ada/results/00001-resizepore-mirror-mirrory-11gb-gpu-bg-resumecustom/network-snapshot-000056.pkl"
#don't edit this unless you know what you're doing :)
# !python train.py --outdir ./results --snap={snapshot_count} --cfg=11gb-gpu --data=./datasets/{dataset_name} --augpipe={augs} --mirror={mirrored} --mirrory={mirroredY} --metrics={metric_list} --resume={resume_from}
# Out:
# tcmalloc: large alloc 4294967296 bytes == 0x56204114c000 @  0x7f2eb057d001 0x7f2ead78054f 0x7f2ead7d0b58 0x7f2ead7d4b17 0x7f2ead873203 0x56203a36a544 0x56203a36a240 0x56203a3de627 0x56203a3d8ced 0x56203a36c48c 0x56203a3ad159 0x56203a3aa0a4 0x56203a36ad49 0x56203a3de94f 0x56203a3d89ee 0x56203a2aae2b 0x56203a3dafe4 0x56203a3d89ee 0x56203a2aae2b 0x56203a3dafe4 0x56203a3d8ced 0x56203a2aae2b 0x56203a3dafe4 0x56203a36bafa 0x56203a3d9915 0x56203a3d89ee 0x56203a3d86f3 0x56203a4a24c2 0x56203a4a283d 0x56203a4a26e6 0x56203a47a163
# ...

# %%
# !python calc_metrics.py --metrics=pr50k3_full \
    --network=/content/drive/MyDrive/colab-sg2-ada/stylegan2-ada/results/00002-resizepore-mirror-mirrory-11gb-gpu-bg-resumecustom/network-snapshot-000104.pkl
# Out:
# Loading network from "/content/drive/MyDrive/colab-sg2-ada/stylegan2-ada/results/00002-resizepore-mirror-mirrory-11gb-gpu-bg-resumecustom/network-snapshot-000104.pkl"...
# Setting up TensorFlow plugin "fused_bias_act.cu": Compiling... Loading... Done.
# Setting up TensorFlow plugin "upfirdn_2d.cu": Compiling... Loading... Done.
#
# Gs                              Params    OutputShape          WeightShape
# ---                             ---       ---                  ---
# latents_in                      -         (?, 512)             -
# labels_in                       -         (?, 0)               -
# G_mapping/Normalize             -         (?, 512)             -
# G_mapping/Dense0                262656    (?, 512)             (512, 512)
# G_mapping/Dense1                262656    (?, 512)             (512, 512)
# G_mapping/Dense2                262656    (?, 512)             (512, 512)
# G_mapping/Dense3                262656    (?, 512)             (512, 512)
# ...

# %%
# !python projector.py --outdir=out --target=/content/drive/MyDrive/colab-sg2-ada/stylegan2-ada/out1043/seed0000.png \
    --network=/content/drive/MyDrive/colab-sg2-ada/stylegan2-ada/results/00002-resizepore-mirror-mirrory-11gb-gpu-bg-resumecustom/network-snapshot-000104.pkl
# Out:
# Loading networks from "/content/drive/MyDrive/colab-sg2-ada/stylegan2-ada/results/00002-resizepore-mirror-mirrory-11gb-gpu-bg-resumecustom/network-snapshot-000104.pkl"...
# Setting up TensorFlow plugin "fused_bias_act.cu": Compiling... Loading... Done.
# Setting up TensorFlow plugin "upfirdn_2d.cu": Compiling... Loading... Done.
# Projector: Computing W midpoint and stddev using 10000 samples...
# Projector: std = 7.16649
# Projector: Setting up noise inputs...
# Projector: Building image output graph...
# Projector: Building loss graph...
# ...
# Projector: Building noise regularization graph...
# Projector: Setting up optimizer...
# Projector: Preparing target images...
# Projector: Initializing optimization state...
# 100% 1000/1000 [04:21<00:00,  3.83it/s, dist=0.1116, loss=0.11]
